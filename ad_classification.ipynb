# %%
import pandas as pd
import nltk
# nltk.download()
from nltk.corpus import stopwords
import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import matplotlib.pyplot as plt

from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from keras.utils.np_utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Import Data
data = pd.read_csv('Videos_data.csv')

# %%
data.head(10)
# Out:
#    Unnamed: 0     Video Id                                              Title  \
# 0           0  ehmsJLZlCZ0  Ep 1| Travelling through North East India | Of...
# 1           1  e2NQE41J5eM    How do I travel so much ! How do I earn money!!
# 2           2  i9E_Blai8vk      TRAVEL VLOG ∙ Welcome to Bali | PRISCILLA LEE
# 3           3       #NAME?  GOA TRAVEL DIARY | FOUR DAYS IN GOA | TRAVEL O...
# 4           4  7ByoBJYXU0k               5 Steps to Becoming a Travel Blogger
# 5           5  yvn79Rv0F48  Backpacking In Meghalaya | NorthEast India Tri...
# 6           6  SL_YBLWdZb8  Welcome to Peru! | Best Essential Tips &amp; T...
# 7           7  kiNyRY5s7n8  How to Start a Travel Blog [2019] Travel Blogg...
# 8           8  kY41XgTEEQU  A Day with KSRTC Bus Fans - Aanavandi Travel B...
# 9           9  7mIzRYh8jGA             What is it like to travel in PAKISTAN?
#
#                                          Description Category
# 0  The journey to Arunachal, North East India beg...   travel
# 1  SUBSCRIBE - https://goo.gl/dEtSMJ ('MountainTr...   travel
# 2  I had the chance to fly out to Bali with my wh...   travel
# 3  Hope you enjoy MY GOA TRAVEL DIARY this video!...   travel
# 4  Travel blogger, Nikki Vargas, of The Pin the M...   travel
# 5  In this video I explored North East India, sta...   travel
# 6  Welcome to Peru! This essential travel guide w...   travel
# 7  Create a Travel Blog Website for Just $3.95 + ...   travel
# 8  ആനവണ്ടി ഭ്രാന്തൻമാരോടൊപ്പം കുമളിയിൽ ഒരു ദിവസം ...   travel
# 9  Subscribe now: https://goo.gl/6zXZGK Watch the...   travel

# %%
data = data.drop(['Unnamed: 0'], axis = 1)

# %%
data.isnull().sum()
# Out:
# Video Id         0
# Title            0
# Description    334
# Category         0
# dtype: int64

# %%
null_data = data[data['Description'].isnull()]

# %%
for i in null_data['Title']:
    dup_data = data[data['Title'] == i ]
    print(dup_data)
# Out:
#        Video Id                   Title Description Category
# 60  DQIuu5qDCyo  ROXAS CITY TRAVEL BLOG         NaN   travel
#         Video Id                                      Title Description  \
# 209  v3v3mPlbJy0  Travel blog: Working some jobs in Rotorua         NaN
# 341  v3v3mPlbJy0  Travel blog: Working some jobs in Rotorua         NaN
#
#     Category
# 209   travel
# 341   travel
#         Video Id                                     Title Description  \
# 213  qdLl1rVW6GE  Hạ Long 2019/Nghỉ lễ đi đâu?/Travel Blog         NaN
#
#     Category
# 213   travel
#         Video Id                                        Title Description  \
# 337  1c7_140xDqQ  Travel blog: Malaysia to Singapore and back         NaN
# 421  1c7_140xDqQ  Travel blog: Malaysia to Singapore and back         NaN
#
#     Category
# 337   travel
# 421   travel
#         Video Id                                      Title Description  \
# 209  v3v3mPlbJy0  Travel blog: Working some jobs in Rotorua         NaN
# 341  v3v3mPlbJy0  Travel blog: Working some jobs in Rotorua         NaN
#
#     Category
# 209   travel
# 341   travel
#         Video Id                                        Title Description  \
# 337  1c7_140xDqQ  Travel blog: Malaysia to Singapore and back         NaN
# 421  1c7_140xDqQ  Travel blog: Malaysia to Singapore and back         NaN
#
#     Category
# 337   travel
# 421   travel
#         Video Id                                              Title  \
# 424  FZoJ1T3VCrA  Travel blog: Egypt  (Cairo-Alexandria-Sharm El...
#
#     Description Category
# 424         NaN   travel
#         Video Id                                     Title Description  \
# 449  Rgwh0xO90m4  Travel blog: Phnom Penh to Sihanoukville         NaN
# 486  Rgwh0xO90m4  Travel blog: Phnom Penh to Sihanoukville         NaN
#
#     Category
# 449   travel
# 486   travel
#         Video Id                                     Title Description  \
# 449  Rgwh0xO90m4  Travel blog: Phnom Penh to Sihanoukville         NaN
# 486  Rgwh0xO90m4  Travel blog: Phnom Penh to Sihanoukville         NaN
#
#     Category
# 449   travel
# 486   travel
#         Video Id                  Title Description Category
# 626  Cm-PsVzuSO8  Kyoto travel blogging         NaN   travel
#         Video Id                                              Title  \
# 666  CTvhwq9z9J0  Tommy Robinson Travelling The Northwest, visit...
#
#     Description Category
# 666         NaN   travel
#         Video Id                    Title Description Category
# 672  l4roQ18RPbw  Travelling Around India         NaN   travel
#          Video Id                                     Title Description  \
# 707   MffeZirTY18  BANGKOK TRAVEL VLOG : TRAVELLING HEMAT !         NaN
# 1352  MffeZirTY18  BANGKOK TRAVEL VLOG : TRAVELLING HEMAT !         NaN
#
#      Category
# 707    travel
# 1352   travel
#          Video Id                            Title Description Category
# 725   f6W7tiYl8ZA  TRAVELLING　近藤房之助 Char PONTA BOX         NaN   travel
# 1337  f6W7tiYl8ZA  TRAVELLING　近藤房之助 Char PONTA BOX         NaN   travel
#      Video Id                  Title Description Category
# 727    #NAME?  El travelling de Kapo         NaN   travel
# 1372   #NAME?  El travelling de Kapo         NaN   travel
#          Video Id                                              Title  \
# 744   sVakQ5aegLY  Chris De Burgh   A Spaceman Came Travelling   ...
# 1386  sVakQ5aegLY  Chris De Burgh   A Spaceman Came Travelling   ...
# 1633  sVakQ5aegLY  Chris De Burgh   A Spaceman Came Travelling   ...
#
#      Description Category
# 744          NaN   travel
# 1386         NaN   travel
# 1633         NaN   travel
#          Video Id                                   Title Description Category
# 758   ogH0FrExBA4  Passenger - Travelling Alone (Español)         NaN   travel
# 1400  ogH0FrExBA4  Passenger - Travelling Alone (Español)         NaN   travel
#          Video Id                                              Title  \
# 776   VuWqeYtCdb8  Travelling from Pokhara to Mustang || Soniya h...
# 1418  VuWqeYtCdb8  Travelling from Pokhara to Mustang || Soniya h...
#
#      Description Category
# 776          NaN   travel
# 1418         NaN   travel
#          Video Id                             Title Description Category
# 805   uG6-awFvOH0  Jeremy Spencer Band - Travelling         NaN   travel
# 1447  uG6-awFvOH0  Jeremy Spencer Band - Travelling         NaN   travel
#          Video Id                                              Title  \
# 838   6V5B5S9dz6A  Travelling with Felicia Singson bluecorn &amp;...
# 1480  6V5B5S9dz6A  Travelling with Felicia Singson bluecorn &amp;...
#
#      Description Category
# 838          NaN   travel
# 1480         NaN   travel
#          Video Id                                              Title  \
# 890   BlC8WhrW_Fk  Aussie Couple 6 months travelling in India | F...
# 1532  BlC8WhrW_Fk  Aussie Couple 6 months travelling in India | F...
#
#      Description Category
# 890          NaN   travel
# 1532         NaN   travel
#          Video Id                                              Title  \
# 900   ndYTyPVFZsQ  TRAVELLING WITH SIBLING IS SUCH A MESS  ( Jamm...
# 1542  ndYTyPVFZsQ  TRAVELLING WITH SIBLING IS SUCH A MESS  ( Jamm...
#
#      Description Category
# 900          NaN   travel
# 1542         NaN   travel
#          Video Id                                              Title  \
# 926   HVlM_6M-Xdw  A Spaceman Came Travelling By Chris De Burgh  ...
# 1568  HVlM_6M-Xdw  A Spaceman Came Travelling By Chris De Burgh  ...
#
#      Description Category
# 926          NaN   travel
# 1568         NaN   travel
#          Video Id                                       Title Description  \
# 971   h1wT9ggwU9s  PAUL DANIELS MAGIC SHOW - TRAVELLING COINS         NaN
# 1613  h1wT9ggwU9s  PAUL DANIELS MAGIC SHOW - TRAVELLING COINS         NaN
#
#      Category
# 971    travel
# 1613   travel
#          Video Id                                              Title  \
# 975   iqDzS-Fgddk  Fiji - A Beautiful Country For People Who Love...
# 1617  iqDzS-Fgddk  Fiji - A Beautiful Country For People Who Love...
#
#      Description Category
# 975          NaN   travel
# 1617         NaN   travel
#          Video Id                 Title Description Category
# 1010  VJ4FxHj9Jbk  Travelling Animation         NaN   travel
#          Video Id                                              Title  \
# 1040  E1qAJ5ARZqw  #travellingindia#explore German solo women tra...
# 1682  E1qAJ5ARZqw  #travellingindia#explore German solo women tra...
#
#      Description Category
# 1040         NaN   travel
# 1682         NaN   travel
#          Video Id         Title Description Category
# 1083  PrE7GfNUqJ8  Travelling-3         NaN   travel
# 1725  PrE7GfNUqJ8  Travelling-3         NaN   travel
#          Video Id                Title Description Category
# 1113  PbhX_CgRjYk  Travellers fighting         NaN   travel
#          Video Id                                Title Description Category
# 1114  CsiQ8YNhEnQ  Pharoah Sanders - Astral Travelling         NaN   travel
#          Video Id                           Title Description Category
# 1133  ripOKLhYu2o  Tommy Tiernan on Travellers...         NaN   travel
#          Video Id                        Title Description Category
# 1140  ReLk-j-slIs  JAMBALAYA (The Travellers )         NaN   travel
#          Video Id                         Title Description Category
# 1148  UOlyNM7tZWg  Travellers popcorns daughter         NaN   travel
#          Video Id                                           Title Description  \
# 1209  1cebDhmqJ58  new age travellers 1993 underground angleterre         NaN
#
#      Category
# 1209   travel
#          Video Id                               Title Description Category
# 1217  PfM0TQZXp_4  Travellers&#39; Century:Laurie Lee         NaN   travel
#          Video Id                                      Title Description  \
# 1232  d-9QW8wBi2c  LGBT Gypsies and Travellers - Our Stories         NaN
#
#      Category
# 1232   travel
#          Video Id                                              Title  \
# 1236  uWcuGo0rEFo  ee cummings reads &quot;Somewhere I have never...
#
#      Description Category
# 1236         NaN   travel
#          Video Id                               Title Description Category
# 1240  BMEk_hdPCqg  Travelling Northen Pakistan Kalash         NaN   travel
#          Video Id                           Title Description Category
# 1265  bWkD3ZggMp8  New Age Travellers - Outsiders         NaN   travel
#          Video Id                                              Title  \
# 1272  EGqBLvZGJfs  Louis Vuitton presents &quot;Travellers&#39; T...
#
#      Description Category
# 1272         NaN   travel
#          Video Id                         Title Description Category
# 1276  IuTN0sTpAmg  First travelling to guwahati         NaN   travel
#          Video Id                        Title Description Category
# 1277  1HJQAT6bwj0  Travelling to rudraprayag..         NaN   travel
#          Video Id                                     Title Description  \
# 1311  RtZg6_yjoeE  BALI TRAVEL VLOG | Ubud - Maryjane Byarm         NaN
#
#      Category
# 1311   travel
#          Video Id                            Title Description Category
# 725   f6W7tiYl8ZA  TRAVELLING　近藤房之助 Char PONTA BOX         NaN   travel
# 1337  f6W7tiYl8ZA  TRAVELLING　近藤房之助 Char PONTA BOX         NaN   travel
#          Video Id                                     Title Description  \
# 707   MffeZirTY18  BANGKOK TRAVEL VLOG : TRAVELLING HEMAT !         NaN
# 1352  MffeZirTY18  BANGKOK TRAVEL VLOG : TRAVELLING HEMAT !         NaN
#
#      Category
# 707    travel
# 1352   travel
#          Video Id                                         Title Description  \
# 1363  AFXay8GlMXs  Travelling the face of the globe - Oi va voi         NaN
#
#      Category
# 1363   travel
#      Video Id                  Title Description Category
# 727    #NAME?  El travelling de Kapo         NaN   travel
# 1372   #NAME?  El travelling de Kapo         NaN   travel
#          Video Id                                              Title  \
# 744   sVakQ5aegLY  Chris De Burgh   A Spaceman Came Travelling   ...
# 1386  sVakQ5aegLY  Chris De Burgh   A Spaceman Came Travelling   ...
# 1633  sVakQ5aegLY  Chris De Burgh   A Spaceman Came Travelling   ...
#
#      Description Category
# 744          NaN   travel
# 1386         NaN   travel
# 1633         NaN   travel
#          Video Id                                   Title Description Category
# 758   ogH0FrExBA4  Passenger - Travelling Alone (Español)         NaN   travel
# 1400  ogH0FrExBA4  Passenger - Travelling Alone (Español)         NaN   travel
#          Video Id                                              Title  \
# 776   VuWqeYtCdb8  Travelling from Pokhara to Mustang || Soniya h...
# 1418  VuWqeYtCdb8  Travelling from Pokhara to Mustang || Soniya h...
#
#      Description Category
# 776          NaN   travel
# 1418         NaN   travel
#          Video Id                             Title Description Category
# 805   uG6-awFvOH0  Jeremy Spencer Band - Travelling         NaN   travel
# 1447  uG6-awFvOH0  Jeremy Spencer Band - Travelling         NaN   travel
#          Video Id                                              Title  \
# 838   6V5B5S9dz6A  Travelling with Felicia Singson bluecorn &amp;...
# 1480  6V5B5S9dz6A  Travelling with Felicia Singson bluecorn &amp;...
#
#      Description Category
# 838          NaN   travel
# 1480         NaN   travel
#          Video Id                                              Title  \
# 890   BlC8WhrW_Fk  Aussie Couple 6 months travelling in India | F...
# 1532  BlC8WhrW_Fk  Aussie Couple 6 months travelling in India | F...
#
#      Description Category
# 890          NaN   travel
# 1532         NaN   travel
#          Video Id                                              Title  \
# 900   ndYTyPVFZsQ  TRAVELLING WITH SIBLING IS SUCH A MESS  ( Jamm...
# 1542  ndYTyPVFZsQ  TRAVELLING WITH SIBLING IS SUCH A MESS  ( Jamm...
#
#      Description Category
# 900          NaN   travel
# 1542         NaN   travel
#          Video Id                                              Title  \
# 926   HVlM_6M-Xdw  A Spaceman Came Travelling By Chris De Burgh  ...
# 1568  HVlM_6M-Xdw  A Spaceman Came Travelling By Chris De Burgh  ...
#
#      Description Category
# 926          NaN   travel
# 1568         NaN   travel
#          Video Id                                       Title Description  \
# 971   h1wT9ggwU9s  PAUL DANIELS MAGIC SHOW - TRAVELLING COINS         NaN
# 1613  h1wT9ggwU9s  PAUL DANIELS MAGIC SHOW - TRAVELLING COINS         NaN
#
#      Category
# 971    travel
# 1613   travel
#          Video Id                                              Title  \
# 975   iqDzS-Fgddk  Fiji - A Beautiful Country For People Who Love...
# 1617  iqDzS-Fgddk  Fiji - A Beautiful Country For People Who Love...
#
#      Description Category
# 975          NaN   travel
# 1617         NaN   travel
#          Video Id                                              Title  \
# 744   sVakQ5aegLY  Chris De Burgh   A Spaceman Came Travelling   ...
# 1386  sVakQ5aegLY  Chris De Burgh   A Spaceman Came Travelling   ...
# 1633  sVakQ5aegLY  Chris De Burgh   A Spaceman Came Travelling   ...
#
#      Description Category
# 744          NaN   travel
# 1386         NaN   travel
# 1633         NaN   travel
#          Video Id            Title Description Category
# 1648  2PbNfYBBmxs  Travelling Time         NaN   travel
#          Video Id                                              Title  \
# 1040  E1qAJ5ARZqw  #travellingindia#explore German solo women tra...
# 1682  E1qAJ5ARZqw  #travellingindia#explore German solo women tra...
#
#      Description Category
# 1040         NaN   travel
# 1682         NaN   travel
#          Video Id         Title Description Category
# 1083  PrE7GfNUqJ8  Travelling-3         NaN   travel
# 1725  PrE7GfNUqJ8  Travelling-3         NaN   travel
#          Video Id                                              Title  \
# 1778  _lA9vgU4uFI  World Dangerous Fast Machines Destroys Everyth...
#
#      Description                Category
# 1778         NaN  science and technology
#          Video Id                                              Title  \
# 1780  7FZQs-2-upA  Primitive Technology - World Modern Agricultur...
#
#      Description                Category
# 1780         NaN  science and technology
#          Video Id                               Title Description  \
# 1806  Hb-qlSCIPM8  Old School Meets Modern Technology         NaN
#
#                     Category
# 1806  science and technology
#          Video Id                                              Title  \
# 1861  zEgT52yZYA0  Future Transport Technology of the next genera...
#
#      Description                Category
# 1861         NaN  science and technology
#          Video Id                                              Title  \
# 1870  Z5n2pH7Q-pU  Technology in families- interpersonal communic...
#
#      Description                Category
# 1870         NaN  science and technology
#          Video Id                                 Title Description  \
# 2184  vHaaI_GbVyg  Information Technology at NUI Galway         NaN
#
#                     Category
# 2184  science and technology
#          Video Id                                              Title  \
# 2187  1TnUKWdFQfI  Ministry of Science and Technology, ROC (English)
# 2429  1TnUKWdFQfI  Ministry of Science and Technology, ROC (English)
#
#      Description                Category
# 2187         NaN  science and technology
# 2429         NaN  science and technology
#          Video Id                                   Title Description  \
# 2210  dx1-_4tlJus  Introduction to Information Technology         NaN
#
#                     Category
# 2210  science and technology
#          Video Id                              Title Description  \
# 2242  8Nwoa6FfOBM  AUDI AI technology demo in the A8         NaN
#
#                     Category
# 2242  science and technology
#          Video Id                            Title Description  \
# 2244  YgWnhS5WyfM  Information Technology Industry         NaN
#
#                     Category
# 2244  science and technology
#          Video Id                       Title Description  \
# 2245  wdMhh0nJQMY  Latest Building Technology         NaN
#
#                     Category
# 2245  science and technology
#          Video Id                                              Title  \
# 2309  yqQs_Zl6hOc  Modern Farming Technology Latest Harvesting Ma...
#
#      Description                Category
# 2309         NaN  science and technology
#          Video Id                                              Title  \
# 2326  IYJ22b4zNZ4  Science and Technology 6 Months Current Affair...
#
#      Description                Category
# 2326         NaN  science and technology
#          Video Id                                              Title  \
# 2345  5d9RU1WgsBI  PT 365 SCIENCE AND TECHNOLOGY 2019 PART 6 VISI...
#
#      Description                Category
# 2345         NaN  science and technology
#          Video Id                                              Title  \
# 2359  cbq6ZgHoSMY  PT 365 SCIENCE AND TECHNOLOGY 2019 PART 7 VISI...
#
#      Description                Category
# 2359         NaN  science and technology
#          Video Id                                              Title  \
# 2379  INd0iqocEL8  Joe Carvalko on the Intersection of Law, Scien...
# 2543  INd0iqocEL8  Joe Carvalko on the Intersection of Law, Scien...
#
#      Description                Category
# 2379         NaN  science and technology
# 2543         NaN  science and technology
#          Video Id                                              Title  \
# 2383  ywbcT2BFuDU  Top 10 Coolest Army Science and Technology Adv...
#
#      Description                Category
# 2383         NaN  science and technology
#          Video Id                                              Title  \
# 2395  sUWTefcLQjE  TU Delft - testimonials MSc Life Science &amp;...
#
#      Description                Category
# 2395         NaN  science and technology
#          Video Id                                              Title  \
# 2187  1TnUKWdFQfI  Ministry of Science and Technology, ROC (English)
# 2429  1TnUKWdFQfI  Ministry of Science and Technology, ROC (English)
#
#      Description                Category
# 2187         NaN  science and technology
# 2429         NaN  science and technology
#          Video Id                                              Title  \
# 2458  EJZXXKJ_Q4k  Science and Technology bits in telugu for aAPP...
#
#      Description                Category
# 2458         NaN  science and technology
#          Video Id                                              Title  \
# 2477  Up_vXfPnoeg  Science and Technology Model Practice Mock Tes...
#
#      Description                Category
# 2477         NaN  science and technology
#          Video Id                                              Title  \
# 2482  tbwOaDTaTMs  Funny speech about girls  university college o...
#
#      Description                Category
# 2482         NaN  science and technology
#          Video Id                                              Title  \
# 2495  UdRCdkdEiqw  Group 2 Mains | Science and technology | Smart...
#
#      Description                Category
# 2495         NaN  science and technology
#          Video Id                                              Title  \
# 2505  YDQJXcseY_w  Faculty of Science and Technology (University ...
#
#      Description                Category
# 2505         NaN  science and technology
#          Video Id                                        Title Description  \
# 2524  nxTPDu5Nibk  Jinwen University of Science and Technology         NaN
#
#                     Category
# 2524  science and technology
#          Video Id                                              Title  \
# 2379  INd0iqocEL8  Joe Carvalko on the Intersection of Law, Scien...
# 2543  INd0iqocEL8  Joe Carvalko on the Intersection of Law, Scien...
#
#      Description                Category
# 2379         NaN  science and technology
# 2543         NaN  science and technology
#          Video Id                                              Title  \
# 2551  ryCYEAtb_Gk  Temple University: Choosing Science and Techno...
#
#      Description                Category
# 2551         NaN  science and technology
#          Video Id                            Title Description  \
# 2555  AUX-BLF-0Jg  Science and Technology Building         NaN
#
#                     Category
# 2555  science and technology
#          Video Id                                              Title  \
# 2566  EAOwhHzgazs  EventsAIR Case Study - Science and Technology ...
#
#      Description                Category
# 2566         NaN  science and technology
#          Video Id                                              Title  \
# 2569  CqfLe0srgK0  About Sudan university of science and technolo...
#
#      Description                Category
# 2569         NaN  science and technology
#          Video Id                                              Title  \
# 2574  hyndfn4YF3A  The Innovation, Science and Technology Buildin...
#
#      Description                Category
# 2574         NaN  science and technology
#          Video Id                                              Title  \
# 2605  8-PaRTiywxk  Where is the Good News? - The Gospel of Scienc...
#
#      Description                Category
# 2605         NaN  science and technology
#          Video Id                                              Title  \
# 2617  MGq_N5cTDjA  Science and Technology Ancient  Ethiopia Amazi...
#
#      Description                Category
# 2617         NaN  science and technology
#          Video Id                                              Title  \
# 2619  FDH6CKyHvA8  Science and Technology question and answer Pra...
#
#      Description                Category
# 2619         NaN  science and technology
#          Video Id                                              Title  \
# 2620  0nTOvM7gvE4  Kubayi-Ngubane laments shortage of women in sc...
#
#      Description                Category
# 2620         NaN  science and technology
#          Video Id                                              Title  \
# 2663  TOzB3HGm7jA  Engineering, Science and Technology Awards - 2015
#
#      Description                Category
# 2663         NaN  science and technology
#          Video Id                                          Title Description  \
# 2665  MTU40QNLrk4  China: Shanghai Science and Technology Museum         NaN
#
#                     Category
# 2665  science and technology
#          Video Id                                              Title  \
# 2730  5PJZz04JGjs  Die Sendung mit der Maus - Wie funktioniert ei...
#
#      Description                Category
# 2730         NaN  science and technology
#          Video Id                           Title Description  \
# 2796  EXZWHumclx0  How do computers store images?         NaN
#
#                     Category
# 2796  science and technology
#          Video Id                                       Title Description  \
# 2897  AJQ3TM-p2QI  Little Britain - Computer Says No - Clip 1         NaN
#
#                     Category
# 2897  science and technology
#          Video Id                           Title Description  \
# 2929  nMjc5OyNvws  Computer &amp; Internet Basics         NaN
#
#                     Category
# 2929  science and technology
#          Video Id                                              Title  \
# 2998  ngK97cSXWoM  Cloud Computing - Computer Science for Busines...
# 3086  ngK97cSXWoM  Cloud Computing - Computer Science for Busines...
#
#      Description                Category
# 2998         NaN  science and technology
# 3086         NaN  science and technology
#          Video Id                      Title Description  \
# 3038  3CLDODvcYw0  Areas in Computer Science         NaN
#
#                     Category
# 3038  science and technology
#          Video Id                                           Title Description  \
# 3061  SbSGJfTj9zw  Research in Computer Science &amp; Engineering         NaN
# 3074  SbSGJfTj9zw  Research in Computer Science &amp; Engineering         NaN
#
#                     Category
# 3061  science and technology
# 3074  science and technology
#          Video Id                                           Title Description  \
# 3061  SbSGJfTj9zw  Research in Computer Science &amp; Engineering         NaN
# 3074  SbSGJfTj9zw  Research in Computer Science &amp; Engineering         NaN
#
#                     Category
# 3061  science and technology
# 3074  science and technology
#          Video Id                                              Title  \
# 2998  ngK97cSXWoM  Cloud Computing - Computer Science for Busines...
# 3086  ngK97cSXWoM  Cloud Computing - Computer Science for Busines...
#
#      Description                Category
# 2998         NaN  science and technology
# 3086         NaN  science and technology
#          Video Id                                  Title Description  \
# 3106  OJd22xoSTNM  Newcleus Computer Age Push the Button         NaN
#
#                     Category
# 3106  science and technology
#          Video Id                                              Title  \
# 3113  svkGASq8mNM  Computer Networking Tutorial for Beginners, Ci...
#
#      Description                Category
# 3113         NaN  science and technology
#          Video Id                                  Title Description  \
# 3120  llZys3xg6sU  Apple iPad Pro  What&#39;s a Computer         NaN
#
#                     Category
# 3120  science and technology
#          Video Id                                              Title  \
# 3248  j-J3BViim0c  De ARRA herinnerd: Een baanbrekende Nederlands...
#
#      Description                Category
# 3248         NaN  science and technology
#          Video Id                   Title Description                Category
# 3373  AeA9R3tTSg0  FUTURE JOBS:  ROBOTICS         NaN  science and technology
#          Video Id                                         Title Description  \
# 3381  cLVCGEmkJs0  Amazon Warehouse Robots : Mind Blowing Video         NaN
#
#                     Category
# 3381  science and technology
#          Video Id                                              Title  \
# 3408  0t2zstQ84Tw  VEX Starstruck - 2016-2017 VEX Robotics Compet...
#
#      Description                Category
# 3408         NaN  science and technology
#          Video Id                                              Title  \
# 3450  iikHeBG38a8  Indian Street Food - SCRAMBLED EGGS PIZZA Mumb...
#
#      Description Category
# 3450         NaN     food
#          Video Id                                              Title  \
# 3550  rtBZhSY_y-M  Japanese Food - PEKING DUCK Chinese Dumplings ...
#
#      Description Category
# 3550         NaN     food
#          Video Id                                              Title  \
# 3589  _ISFiW-A2B8  Hong Kong Street Food. Chopping Piglets, Ducks...
#
#      Description Category
# 3589         NaN     food
#          Video Id                                              Title  \
# 3629  lfIAGlR6CJw  Japanese Street Food - GIANT SQUID Fried Calam...
#
#      Description Category
# 3629         NaN     food
#          Video Id                                              Title  \
# 3640  H9JCYdj9Zfs  Taiwanese Street Food - SPICY CHILI CHEESE CHI...
#
#      Description Category
# 3640         NaN     food
#          Video Id                          Title Description Category
# 3644  mROjU_oV9xc  Family Guy - Peter sells Food         NaN     food
#          Video Id                                              Title  \
# 3648  t3ABrLCMrKQ  Japanese Food - GIANT GOLIATH GROUPER Sushi Te...
#
#      Description Category
# 3648         NaN     food
#          Video Id                                     Title Description  \
# 3813  R_Rof46gJbA  Fast Food Babies - BBC Three Documentary         NaN
#
#      Category
# 3813     food
#          Video Id                    Title Description Category
# 3902  LnfpeBdZsZ0  The Right to Food -  EN         NaN     food
#          Video Id     Title Description Category
# 3910  jCWpt8r-2WU  Big Food         NaN     food
#          Video Id                    Title Description Category
# 3949  nk-iY5O6CTg  BIZARRE FOODS - MOROCCO         NaN     food
#          Video Id                                              Title  \
# 4067  LHAgUebnlXI  Japanese Street Food - $600 GIANT RAINBOW LOBS...
#
#      Description Category
# 4067         NaN     food
#          Video Id                 Title Description Category
# 4076  f2OMVu6wU7g  Cooking Turkey Necks         NaN     food
#          Video Id                            Title Description Category
# 4087  kv_J_QJMQpU  Thanos cooking scene in endgame         NaN     food
#          Video Id                                              Title  \
# 4346  yyMUUWW7TG4  How to Catch, Clean and Cook a Snapping Turtle...
#
#      Description Category
# 4346         NaN     food
#          Video Id                                              Title  \
# 4362  IX46xUQ4Lec  What A Beautiful Name + Spontaneous Worship - ...
# 4372  IX46xUQ4Lec  What A Beautiful Name + Spontaneous Worship - ...
#
#      Description Category
# 4362         NaN     food
# 4372         NaN     food
#          Video Id                                              Title  \
# 4362  IX46xUQ4Lec  What A Beautiful Name + Spontaneous Worship - ...
# 4372  IX46xUQ4Lec  What A Beautiful Name + Spontaneous Worship - ...
#
#      Description Category
# 4362         NaN     food
# 4372         NaN     food
#          Video Id                                              Title  \
# 4399  KkYfAEFR03Q  How to Catch, Clean and Cook a Snapping Turtle...
#
#      Description Category
# 4399         NaN     food
#          Video Id                                     Title Description  \
# 4410  pMpeAixF6-A  Per Löfberg   EMERGING cooking solutions         NaN
#
#      Category
# 4410     food
#          Video Id                                              Title  \
# 4412  ovB9Ttaj1Pg  Improved Nature® PrimeProTex® Tenders   Cookin...
# 4424  ovB9Ttaj1Pg  Improved Nature® PrimeProTex® Tenders   Cookin...
#
#      Description Category
# 4412         NaN     food
# 4424         NaN     food
#          Video Id                                              Title  \
# 4412  ovB9Ttaj1Pg  Improved Nature® PrimeProTex® Tenders   Cookin...
# 4424  ovB9Ttaj1Pg  Improved Nature® PrimeProTex® Tenders   Cookin...
#
#      Description Category
# 4412         NaN     food
# 4424         NaN     food
#          Video Id                           Title Description Category
# 4435  qMt3nYoCXq4  Cooking Matters in Arkansas HD         NaN     food
#          Video Id                                          Title Description  \
# 4483  kVhOLkIs20A  Keynote address from Tim Cook, CEO, Apple Inc         NaN
#
#      Category
# 4483     food
#          Video Id                                              Title  \
# 4605  8yDeUkqi-K0  TRAVELING TO DUBAI &amp; EATING ON THE GO - Ch...
#
#      Description Category
# 4605         NaN     food
#          Video Id                                              Title  \
# 4609  tM1_P_chL70  Eating Bangladeshi Snacks (puri,samucha,singar...
# 4718  tM1_P_chL70  Eating Bangladeshi Snacks (puri,samucha,singar...
#
#      Description Category
# 4609         NaN     food
# 4718         NaN     food
#          Video Id                                              Title  \
# 4609  tM1_P_chL70  Eating Bangladeshi Snacks (puri,samucha,singar...
# 4718  tM1_P_chL70  Eating Bangladeshi Snacks (puri,samucha,singar...
#
#      Description Category
# 4609         NaN     food
# 4718         NaN     food
#          Video Id                                          Title Description  \
# 4881  h4-WjnodISs  Jokes: When Your Friends Eat All Your Snacks!         NaN
#
#      Category
# 4881     food
#          Video Id                         Title Description Category
# 4973  VvPJvfPP0WU  snacks eating challenge kids         NaN     food
#          Video Id                          Title Description       Category
# 5210  R9J7pOU5FSg  Sugar Manufacturing Video.FLV         NaN  manufacturing
# 5854  R9J7pOU5FSg  Sugar Manufacturing Video.FLV         NaN  manufacturing
#      Video Id                                   Title Description  \
# 5234   #NAME?  VinFast eScooter Manufacturing Process         NaN
# 5876   #NAME?  VinFast eScooter Manufacturing Process         NaN
#
#            Category
# 5234  manufacturing
# 5876  manufacturing
#          Video Id                                      Title Description  \
# 5298  i8kxymmjdoM  Semiconductor manufacturing process video         NaN
# 5941  i8kxymmjdoM  Semiconductor manufacturing process video         NaN
#
#            Category
# 5298  manufacturing
# 5941  manufacturing
#          Video Id                      Title Description       Category
# 5320  US3Zt7_1Wjk  Seamless Pipe manufacture         NaN  manufacturing
# 6004  US3Zt7_1Wjk  Seamless Pipe manufacture         NaN  manufacturing
#          Video Id                      Title Description       Category
# 5333  Z92XGAHp5Cs  Diversified Manufacturing         NaN  manufacturing
#          Video Id               Title Description       Category
# 5346  BSvYHSd8rKA  Wise Manufacturing         NaN  manufacturing
# 5364  BSvYHSd8rKA  Wise Manufacturing         NaN  manufacturing
# 6007  BSvYHSd8rKA  Wise Manufacturing         NaN  manufacturing
#          Video Id               Title Description       Category
# 5346  BSvYHSd8rKA  Wise Manufacturing         NaN  manufacturing
# 5364  BSvYHSd8rKA  Wise Manufacturing         NaN  manufacturing
# 6007  BSvYHSd8rKA  Wise Manufacturing         NaN  manufacturing
#          Video Id                                              Title  \
# 5366  wJN8sqMqfGM  Rolls-Royce | Manufacturing Process Engineer, ...
# 6009  wJN8sqMqfGM  Rolls-Royce | Manufacturing Process Engineer, ...
#
#      Description       Category
# 5366         NaN  manufacturing
# 6009         NaN  manufacturing
#          Video Id                                            Title  \
# 5384  6ISddRRHAhA  Introduction to Manufacturing Process Tecnology
# 6027  6ISddRRHAhA  Introduction to Manufacturing Process Tecnology
#
#      Description       Category
# 5384         NaN  manufacturing
# 6027         NaN  manufacturing
#          Video Id                                 Title Description  \
# 5412  vtdFAQHAGzc  Tablet Manufacturing Process Part B.         NaN
# 6055  vtdFAQHAGzc  Tablet Manufacturing Process Part B.         NaN
#
#            Category
# 5412  manufacturing
# 6055  manufacturing
#          Video Id                                    Title Description  \
# 5415  bAKBX2VoMn0  JK Lakshmi Cement Manufacturing Process         NaN
# 6058  bAKBX2VoMn0  JK Lakshmi Cement Manufacturing Process         NaN
#
#            Category
# 5415  manufacturing
# 6058  manufacturing
#          Video Id                                        Title Description  \
# 5441  vVkqxzkN0bM  aac block manufacturing process in pakistan         NaN
# 6085  vVkqxzkN0bM  aac block manufacturing process in pakistan         NaN
#
#            Category
# 5441  manufacturing
# 6085  manufacturing
#          Video Id                               Title Description  \
# 5462  zzwEPqYzXyI  Safety Shoes Manufacturing process         NaN
# 6105  zzwEPqYzXyI  Safety Shoes Manufacturing process         NaN
#
#            Category
# 5462  manufacturing
# 6105  manufacturing
#          Video Id                   Title Description       Category
# 5488  XrZgRCWH3No  Capsules Manufacturing         NaN  manufacturing
# 6131  XrZgRCWH3No  Capsules Manufacturing         NaN  manufacturing
#          Video Id                                      Title Description  \
# 5571  1af5N6EZbD4  Changing Minds About Modern Manufacturing         NaN
#
#            Category
# 5571  manufacturing
#          Video Id                     Title Description       Category
# 5587  cWL6QQuRuxE  Solar Cell Manufacturing         NaN  manufacturing
# 6234  cWL6QQuRuxE  Solar Cell Manufacturing         NaN  manufacturing
#          Video Id                           Title Description       Category
# 5591  Q8s1dulkusQ  Clickstop Inc. - Manufacturing         NaN  manufacturing
#          Video Id                                             Title  \
# 5594  Mm7yAHIODpk  Post Manufacturing Economy - Artley - technology
# 5658  Mm7yAHIODpk  Post Manufacturing Economy - Artley - technology
# 6301  Mm7yAHIODpk  Post Manufacturing Economy - Artley - technology
#
#      Description       Category
# 5594         NaN  manufacturing
# 5658         NaN  manufacturing
# 6301         NaN  manufacturing
#          Video Id                                           Title Description  \
# 5603  DksYJqtNcX8  First Solar&#39;s Module Manufacturing Process         NaN
# 6212  DksYJqtNcX8  First Solar&#39;s Module Manufacturing Process         NaN
#
#            Category
# 5603  manufacturing
# 6212  manufacturing
#          Video Id             Title Description       Category
# 5612  F-wqP4z9VPI  AO Manufacturing         NaN  manufacturing
# 6214  F-wqP4z9VPI  AO Manufacturing         NaN  manufacturing
#          Video Id              Title Description       Category
# 5615  wvcqccm9eX8  SAS Manufacturing         NaN  manufacturing
# 6258  wvcqccm9eX8  SAS Manufacturing         NaN  manufacturing
#          Video Id                                            Title  \
# 5637  X1yPO1TVG1Y  Manufacturing Process Series. Adjustable Wrench
# 6280  X1yPO1TVG1Y  Manufacturing Process Series. Adjustable Wrench
#
#      Description       Category
# 5637         NaN  manufacturing
# 6280         NaN  manufacturing
#          Video Id                                             Title  \
# 5594  Mm7yAHIODpk  Post Manufacturing Economy - Artley - technology
# 5658  Mm7yAHIODpk  Post Manufacturing Economy - Artley - technology
# 6301  Mm7yAHIODpk  Post Manufacturing Economy - Artley - technology
#
#      Description       Category
# 5594         NaN  manufacturing
# 5658         NaN  manufacturing
# 6301         NaN  manufacturing
#          Video Id                                              Title  \
# 5673  cFwgFjgukh0  Indiana Chamber Foundation Manufacturing Pathw...
# 6316  cFwgFjgukh0  Indiana Chamber Foundation Manufacturing Pathw...
#
#      Description       Category
# 5673         NaN  manufacturing
# 6316         NaN  manufacturing
#          Video Id                          Title Description       Category
# 5688  s2OWCpfuA2U  N0505B  Manufacturing Account         NaN  manufacturing
# 6331  s2OWCpfuA2U  N0505B  Manufacturing Account         NaN  manufacturing
#          Video Id                             Title Description       Category
# 5704  Fomi0V_xl4k  Five Axis Additive Manufacturing         NaN  manufacturing
# 6347  Fomi0V_xl4k  Five Axis Additive Manufacturing         NaN  manufacturing
#          Video Id                                 Title Description  \
# 5710  0A6gzBTmK08  Tablet Manufacturing Process Part A.         NaN
# 6353  0A6gzBTmK08  Tablet Manufacturing Process Part A.         NaN
#
#            Category
# 5710  manufacturing
# 6353  manufacturing
#          Video Id                      Title Description       Category
# 5730  Xl1knk2KPp0  LCD Manufacturing Process         NaN  manufacturing
# 6373  Xl1knk2KPp0  LCD Manufacturing Process         NaN  manufacturing
#          Video Id                      Title Description       Category
# 5733  n4FCiS2QIBU  Manufacturing Engineering         NaN  manufacturing
# 6376  n4FCiS2QIBU  Manufacturing Engineering         NaN  manufacturing
#          Video Id                               Title  \
# 5382  ZdHGTCXcJQU  Introduction to Lean Manufacturing
# 5754  mYq3tP7RArE  Introduction to Lean Manufacturing
# 6025  ZdHGTCXcJQU  Introduction to Lean Manufacturing
# 6397  mYq3tP7RArE  Introduction to Lean Manufacturing
#
#                                             Description       Category
# 5382  http://gembaacademy.com | A brief introduction...  manufacturing
# 5754                                                NaN  manufacturing
# 6025  http://gembaacademy.com | A brief introduction...  manufacturing
# 6397                                                NaN  manufacturing
#          Video Id                                              Title  \
# 5798  MFA4vR-n9T4  Kaizen/Lean in manufacturing industry (Toyota)...
# 6441  MFA4vR-n9T4  Kaizen/Lean in manufacturing industry (Toyota)...
#
#      Description       Category
# 5798         NaN  manufacturing
# 6441         NaN  manufacturing
#          Video Id                          Title Description       Category
# 5210  R9J7pOU5FSg  Sugar Manufacturing Video.FLV         NaN  manufacturing
# 5854  R9J7pOU5FSg  Sugar Manufacturing Video.FLV         NaN  manufacturing
#      Video Id                                   Title Description  \
# 5234   #NAME?  VinFast eScooter Manufacturing Process         NaN
# 5876   #NAME?  VinFast eScooter Manufacturing Process         NaN
#
#            Category
# 5234  manufacturing
# 5876  manufacturing
#          Video Id                                      Title Description  \
# 5298  i8kxymmjdoM  Semiconductor manufacturing process video         NaN
# 5941  i8kxymmjdoM  Semiconductor manufacturing process video         NaN
#
#            Category
# 5298  manufacturing
# 5941  manufacturing
#          Video Id                                 Title Description  \
# 5987  uI1qbqkLmI8  Optical Fiber Cables Manufacturing 2         NaN
#
#            Category
# 5987  manufacturing
#          Video Id                                       Title Description  \
# 5993  AnrBQEAM3rE  Noam Chomsky- Manufacturing consent (1992)         NaN
#
#            Category
# 5993  manufacturing
#          Video Id                      Title Description       Category
# 5320  US3Zt7_1Wjk  Seamless Pipe manufacture         NaN  manufacturing
# 6004  US3Zt7_1Wjk  Seamless Pipe manufacture         NaN  manufacturing
#          Video Id               Title Description       Category
# 5346  BSvYHSd8rKA  Wise Manufacturing         NaN  manufacturing
# 5364  BSvYHSd8rKA  Wise Manufacturing         NaN  manufacturing
# 6007  BSvYHSd8rKA  Wise Manufacturing         NaN  manufacturing
#          Video Id                                              Title  \
# 5366  wJN8sqMqfGM  Rolls-Royce | Manufacturing Process Engineer, ...
# 6009  wJN8sqMqfGM  Rolls-Royce | Manufacturing Process Engineer, ...
#
#      Description       Category
# 5366         NaN  manufacturing
# 6009         NaN  manufacturing
#          Video Id                                            Title  \
# 5384  6ISddRRHAhA  Introduction to Manufacturing Process Tecnology
# 6027  6ISddRRHAhA  Introduction to Manufacturing Process Tecnology
#
#      Description       Category
# 5384         NaN  manufacturing
# 6027         NaN  manufacturing
#          Video Id                                 Title Description  \
# 5412  vtdFAQHAGzc  Tablet Manufacturing Process Part B.         NaN
# 6055  vtdFAQHAGzc  Tablet Manufacturing Process Part B.         NaN
#
#            Category
# 5412  manufacturing
# 6055  manufacturing
#          Video Id                                    Title Description  \
# 5415  bAKBX2VoMn0  JK Lakshmi Cement Manufacturing Process         NaN
# 6058  bAKBX2VoMn0  JK Lakshmi Cement Manufacturing Process         NaN
#
#            Category
# 5415  manufacturing
# 6058  manufacturing
#          Video Id                                        Title Description  \
# 5441  vVkqxzkN0bM  aac block manufacturing process in pakistan         NaN
# 6085  vVkqxzkN0bM  aac block manufacturing process in pakistan         NaN
#
#            Category
# 5441  manufacturing
# 6085  manufacturing
#          Video Id                               Title Description  \
# 5462  zzwEPqYzXyI  Safety Shoes Manufacturing process         NaN
# 6105  zzwEPqYzXyI  Safety Shoes Manufacturing process         NaN
#
#            Category
# 5462  manufacturing
# 6105  manufacturing
#          Video Id                   Title Description       Category
# 5488  XrZgRCWH3No  Capsules Manufacturing         NaN  manufacturing
# 6131  XrZgRCWH3No  Capsules Manufacturing         NaN  manufacturing
#          Video Id                                           Title Description  \
# 5603  DksYJqtNcX8  First Solar&#39;s Module Manufacturing Process         NaN
# 6212  DksYJqtNcX8  First Solar&#39;s Module Manufacturing Process         NaN
#
#            Category
# 5603  manufacturing
# 6212  manufacturing
#          Video Id             Title Description       Category
# 5612  F-wqP4z9VPI  AO Manufacturing         NaN  manufacturing
# 6214  F-wqP4z9VPI  AO Manufacturing         NaN  manufacturing
#          Video Id                     Title Description       Category
# 5587  cWL6QQuRuxE  Solar Cell Manufacturing         NaN  manufacturing
# 6234  cWL6QQuRuxE  Solar Cell Manufacturing         NaN  manufacturing
#          Video Id               Title Description       Category
# 6241  KiM5uP7J-pw  SCANIA Manufacture         NaN  manufacturing
#          Video Id                               Title Description  \
# 6253  URZWNnkZlYg  Manufacturing Engineering Overview         NaN
#
#            Category
# 6253  manufacturing
#          Video Id              Title Description       Category
# 5615  wvcqccm9eX8  SAS Manufacturing         NaN  manufacturing
# 6258  wvcqccm9eX8  SAS Manufacturing         NaN  manufacturing
#          Video Id                                            Title  \
# 5637  X1yPO1TVG1Y  Manufacturing Process Series. Adjustable Wrench
# 6280  X1yPO1TVG1Y  Manufacturing Process Series. Adjustable Wrench
#
#      Description       Category
# 5637         NaN  manufacturing
# 6280         NaN  manufacturing
#          Video Id                                             Title  \
# 5594  Mm7yAHIODpk  Post Manufacturing Economy - Artley - technology
# 5658  Mm7yAHIODpk  Post Manufacturing Economy - Artley - technology
# 6301  Mm7yAHIODpk  Post Manufacturing Economy - Artley - technology
#
#      Description       Category
# 5594         NaN  manufacturing
# 5658         NaN  manufacturing
# 6301         NaN  manufacturing
#          Video Id                                              Title  \
# 5673  cFwgFjgukh0  Indiana Chamber Foundation Manufacturing Pathw...
# 6316  cFwgFjgukh0  Indiana Chamber Foundation Manufacturing Pathw...
#
#      Description       Category
# 5673         NaN  manufacturing
# 6316         NaN  manufacturing
#          Video Id                          Title Description       Category
# 5688  s2OWCpfuA2U  N0505B  Manufacturing Account         NaN  manufacturing
# 6331  s2OWCpfuA2U  N0505B  Manufacturing Account         NaN  manufacturing
#          Video Id                             Title Description       Category
# 5704  Fomi0V_xl4k  Five Axis Additive Manufacturing         NaN  manufacturing
# 6347  Fomi0V_xl4k  Five Axis Additive Manufacturing         NaN  manufacturing
#          Video Id                                 Title Description  \
# 5710  0A6gzBTmK08  Tablet Manufacturing Process Part A.         NaN
# 6353  0A6gzBTmK08  Tablet Manufacturing Process Part A.         NaN
#
#            Category
# 5710  manufacturing
# 6353  manufacturing
#          Video Id                      Title Description       Category
# 5730  Xl1knk2KPp0  LCD Manufacturing Process         NaN  manufacturing
# 6373  Xl1knk2KPp0  LCD Manufacturing Process         NaN  manufacturing
#          Video Id                      Title Description       Category
# 5733  n4FCiS2QIBU  Manufacturing Engineering         NaN  manufacturing
# 6376  n4FCiS2QIBU  Manufacturing Engineering         NaN  manufacturing
#          Video Id                               Title  \
# 5382  ZdHGTCXcJQU  Introduction to Lean Manufacturing
# 5754  mYq3tP7RArE  Introduction to Lean Manufacturing
# 6025  ZdHGTCXcJQU  Introduction to Lean Manufacturing
# ...
#
#      Description Category
# 7846         NaN  history
#          Video Id                                    Title Description  \
# 7848  6BQ50bnBKI0  Introduction to Biological Anthropology         NaN
#
#      Category
# 7848  history
#          Video Id                   Title  \
# 7656  U5zD_1J_WeQ  Ethics in Anthropology
# 7862  8ex51uXKgGU  Ethics in Anthropology
#
#                                             Description Category
# 7656  The Dartmouth Ethnography Lab brings you an An...  history
# 7862                                                NaN  history
#          Video Id                                              Title  \
# 7872  LtNYSRd1wDk  Jesus Christ, Judas are Akufo-Addo’s ancestors...
#
#      Description Category
# 7872         NaN  history
#          Video Id                                              Title  \
# 7883  gZwNizaUxno  anthropology EC741156 E967 480D B112 C3EC9B684E36
#
#      Description Category
# 7883         NaN  history
#          Video Id               Title Description Category
# 7894  Glb3aIiplx4  Anthropology video         NaN  history
#          Video Id                               Title Description Category
# 7901  NzHBmUvFxfI  Anthropology Grad Student Research         NaN  history
#          Video Id                                              Title  \
# 7902  zMN9AXDwjAI  Anthropology Videoproject   Plans - Labastida ...
#
#      Description Category
# 7902         NaN  history
#          Video Id                                              Title  \
# 7910  3BKI3_Ip-lk  Talal Asad Revisits &quot;The Idea of an Anthr...
#
#      Description Category
# 7910         NaN  history
#          Video Id                                              Title  \
# 7915  A4Hu3D5_I7o  UC San Diego 2017 Anthropology Honors Thesis P...
#
#      Description Category
# 7915         NaN  history
#          Video Id                                   Title Description Category
# 7922  uJHbuMSdyho  Digital Anthropology Social Experiment         NaN  history
#      Video Id                                         Title Description  \
# 7929   #NAME?  Final presentation Medical Anthropology NMSU         NaN
#
#      Category
# 7929  history
#      Video Id                                              Title Description  \
# 7933   #NAME?  UC San Diego 2016 Anthropology Honors Thesis P...         NaN
#
#      Category
# 7933  history
#          Video Id                               Title Description Category
# 7934  f4QFXI1wbfc  Geertz&#39;s Cultural Anthropology         NaN  history
#          Video Id                                              Title  \
# 7940  z0ueRajomNk  Anthropology Online Class ... Mihir  Sir WBCS exe
#
#      Description Category
# 7940         NaN  history
#          Video Id                                              Title  \
# 7941  CrWESsGW5d0  Dimoria College Farewell Department of Anthrop...
#
#      Description Category
# 7941         NaN  history
#          Video Id                                              Title  \
# 7943  Qz0Y1GdpQ5w  Partnering Anthropology and Evaluation: What d...
#
#      Description Category
# 7943         NaN  history
#          Video Id                                              Title  \
# 7944  kvhHFAVFflU  Anthropologist Daniel Vachon discusses Aborigi...
#
#      Description Category
# 7944         NaN  history
#          Video Id                                              Title  \
# 7957  iwkxu7JxM14  Conversation With Professor Asmarom Legesse , ...
#
#      Description Category
# 7957         NaN  history
#          Video Id                    Title Description Category
# 7962  3BvxcFe1Jgk  Anthropology homework 3         NaN  history
#          Video Id                            Title Description Category
# 7963  l7KsjyxGRVA  Anthropology Video Presentation         NaN  history
#          Video Id                   Title Description Category
# 7964  38fqUJZ7P9c  ANTHROPOLOGY-[version]         NaN  history
#          Video Id                                              Title  \
# 7965  t6GFd2SYxzY  UPSC 2018 Topper I Anthropology Preparation St...
#
#      Description Category
# 7965         NaN  history
#          Video Id                       Title Description Category
# 7967  qzhmu-yqSR0  entrevista anthropology :v         NaN  history
#          Video Id                                              Title  \
# 7971  ZmKrJlpdHAI  Anthropologist Nikhil Anand, Urban Planner Rah...
#
#      Description Category
# 7971         NaN  history
#          Video Id                              Title Description Category
# 7972  9MEFw-cf5Q0  screencast test- Anthropology 102         NaN  history
#          Video Id                               Title Description Category
# 7987  z4OXiZNi3z0  Karl Pilkington the Anthropologist         NaN  history
#          Video Id                                              Title  \
# 7990  xtxp2AlQdP4  Jesus Christ was a Ghanaian, an Akyem – Anthro...
#
#      Description Category
# 7990         NaN  history
#          Video Id                                              Title  \
# 8003  IZ3LrLI5LzE  Ceramic Composition with Dr  Lindsay Bloch Flo...
#
#      Description Category
# 8003         NaN  history
#          Video Id                          Title Description Category
# 8026  5Cr6VUboOr0  CAREER IN ARCHAEOLOGY PART  1         NaN  history
#          Video Id                                           Title Description  \
# 8052  X-I3MgojE0w  The Story Of Archaeology 1of6-Stones And Bones         NaN
#
#      Category
# 8052  history
#          Video Id                                              Title  \
# 8055  f_WctDgr_zk  The Latest Biblical Archaeological Discoveries...
#
#      Description Category
# 8055         NaN  history
#          Video Id                             Title Description Category
# 8104  N-L9exK-5pg  Eddie Izzard - Speed Archaeology         NaN  history
#          Video Id                                              Title  \
# 8161  7Wj-0GiishA  ARCHAEOLOGY discoveries A Place Called EPHESUS...
#
#      Description Category
# 8161         NaN  history
#          Video Id                                            Title  \
# 8166  1QJcGudbfVA  History of the Faculty of Archaeology in leiden
#
#      Description Category
# 8166         NaN  history
#          Video Id                                              Title  \
# 8178  rmYBAknx0UE  HISTORY COLD CASE - The York 113 (BBC Archaeol...
#
#      Description Category
# 8178         NaN  history
#          Video Id                                              Title  \
# 8218  z61InwzlgWM  Louisiana Office of Cultural Development - Arc...
#
#      Description Category
# 8218         NaN  history
#          Video Id                                       Title Description  \
# 8266  WE6D3nKGzbE  Archaeological Research Services Ltd Video         NaN
#
#      Category
# 8266  history
#          Video Id                                              Title  \
# 8292  R21zogvzC2s  Harappan Archaeology objective || Class 12th H...
#
#      Description Category
# 8292         NaN  history
#          Video Id                                              Title  \
# 8362  r2a9wCW9uT4  Craig Lee-Ice Patch Archaeology at Crossroads ...
#
#      Description Category
# 8362         NaN  history
#          Video Id                                  Title Description Category
# 8379  z-Qgkx5vwJE  Student archaeology research projects         NaN  history
#          Video Id                                              Title  \
# 8402  uLW3Y6XD-Io  MNM 360 | Church of Santa Maria Trastevere | M...
#
#      Description Category
# 8402         NaN  history
#          Video Id                                              Title  \
# 8429  tSKqCELy9jY  Whitworth Park Community Archaeology and Histo...
#
#      Description Category
# 8429         NaN  history
#          Video Id                       Title Description Category
# 8441  TPxTbjSsNWM  Archaeology in Sheshatshiu         NaN  history
#          Video Id                                              Title  \
# 8483  rsEKRzdrsZw  Visiting Deranged Archaeologist again (after g...
#
#      Description Category
# 8483         NaN  history
#          Video Id                          Title Description Category
# 8503  faJ9yfEevmQ  Why is archaeology important?         NaN  history
#          Video Id                     Title Description Category
# 8531  IISJPUg-M8w  Archaeologist Andy S3x02         NaN  history
#          Video Id                                              Title  \
# 8555  kH7w77h8_F8  ARCHAEOLOGICAL COVERUPS BY DAVID HATCHER CHILD...
#
#      Description Category
# 8555         NaN  history
#          Video Id                                              Title  \
# 8567  tGoarO0ualI  11th National Annual Conference on Ancient Sci...
#
#      Description Category
# 8567         NaN  history
#          Video Id                                              Title  \
# 8583  CYqMAph4jQY  History of the Faculty of Archaeology Leiden U...
#
#      Description Category
# 8583         NaN  history
#          Video Id                         Title Description Category
# 8612  yptzkW6oj9E  Biblical Archaeology Project         NaN  history
#          Video Id                   Title Description       Category
# 8738  MyK1JBYJOTs  Seasons art and crafts         NaN  art and music
#          Video Id                                        Title Description  \
# 8770  AyluJqLPT5s  O Brother, Where Art Thou (2000) Show scene         NaN
#
#            Category
# 8770  art and music
#          Video Id           Title Description       Category
# 8872  U79dVXFCF4o  Art Basel 2014         NaN  art and music
#          Video Id               Title Description       Category
# 8949  dQo8DGAvHFo  The ART of COONING         NaN  art and music
#          Video Id                                     Title Description  \
# 9014  35FILs1qiVA  George Beverly Shea   How Great Thou Art         NaN
#
#            Category
# 9014  art and music
#          Video Id                    Title Description       Category
# 9017  HTr7bqKHvgE  Gojira-The Art Of Dying         NaN  art and music
#          Video Id                 Title Description       Category
# 9086  XndDglp_GA8  Cataloghi Inside Art         NaN  art and music
#          Video Id                            Title Description       Category
# 9091  7HDRLnoAY9E  Art Donovan on The Tonight Show         NaN  art and music
#          Video Id                                     Title Description  \
# 9579  3ZSPyqEgCIo  Thank you notes music -Jimmy Fallon show         NaN
#
#            Category
# 9579  art and music
#          Video Id             Title Description       Category
# 9589  MK6TXMsvgQg  Benny Hill Theme         NaN  art and music
#          Video Id                                              Title  \
# 9649  _q_OnUjF0W0  Oscar Bernard Tapie, Chantal Ladessou theatre ...
# 9695  _q_OnUjF0W0  Oscar Bernard Tapie, Chantal Ladessou theatre ...
#
#      Description       Category
# 9649         NaN  art and music
# 9695         NaN  art and music
#          Video Id                                              Title  \
# 9673  4spq8-AYuAM  wally seck verse de chaudes larmes au grand th...
#
#      Description       Category
# 9673         NaN  art and music
#          Video Id                                              Title  \
# 9675  64Ejh4mb1T4  Avengers endgame indian theatre reaction (spoi...
#
#      Description       Category
# 9675         NaN  art and music
#          Video Id                                              Title  \
# 9678  WTwK9nbsJig  la soupiere Micheline Dax Rger Pierre theatre ...
#
#      Description       Category
# 9678         NaN  art and music
#          Video Id                                     Title Description  \
# 9680  tv6AKhi5G20  Avengers endgame theatre reaction kerala         NaN
#
#            Category
# 9680  art and music
#          Video Id                                              Title  \
# 9649  _q_OnUjF0W0  Oscar Bernard Tapie, Chantal Ladessou theatre ...
# 9695  _q_OnUjF0W0  Oscar Bernard Tapie, Chantal Ladessou theatre ...
#
#      Description       Category
# 9649         NaN  art and music
# 9695         NaN  art and music
#          Video Id                                     Title Description  \
# 9712  Z2TQhXhN_L4  THEATRE SANEKH 2015 Tolof Tolof Partie 1         NaN
#
#            Category
# 9712  art and music
#          Video Id                                              Title  \
# 9716  _R9JoGFt1zY  Maharshi teaser in theatre//maheshbabu craze /...
#
#      Description       Category
# 9716         NaN  art and music
#          Video Id                                Title Description  \
# 9717  _USiKvJfdVU  Globe Theatre Model Assembly Part 1         NaN
#
#            Category
# 9717  art and music
#          Video Id                                             Title  \
# 9729  gWU6399j_lA  Shazam | Transformation Scene | Theatre Reaction
#
#      Description       Category
# 9729         NaN  art and music
#          Video Id                          Title Description       Category
# 9731  RWVBbM16Wos  theatre senegalais SANEX vol1         NaN  art and music
#          Video Id                                              Title  \
# 9737  ltpTYH6gIEs  Avengers Endgame All Avengers Enterance Audien...
#
#      Description       Category
# 9737         NaN  art and music
#          Video Id                               Title Description  \
# 9741  Oaheuvtxjvs  AVENGERS END GAME THEATRE RESPONSE         NaN
#
#            Category
# 9741  art and music
#          Video Id                                              Title  \
# 9760  IYqvH66Hhwo  Au theatre ce soir   Quelle famille   DvDRiP f...
#
#      Description       Category
# 9760         NaN  art and music
#          Video Id                              Title Description  \
# 9787  -8D6fN3HF5g  AVENGERS ENDGAME REACTION THEATRE         NaN
#
#            Category
# 9787  art and music
#          Video Id                                     Title Description  \
# 9793  MlQ4UYgDjxs  Avengers END GAME Best Theatre Reactions         NaN
#
#            Category
# 9793  art and music
#           Video Id                     Title Description       Category
# 10052  pGZBc2sRqKY  Theatre of Tragedy,Siren         NaN  art and music
#           Video Id                                              Title  \
# 10069  xLMbf7E5Uxo  Alexander Borodin  Prince Igor   Polovtsian Da...
#
#       Description       Category
# 10069         NaN  art and music
#           Video Id                       Title Description       Category
# 10082  P1frxLDT0CQ  Brandon Bate, SAMC Theatre         NaN  art and music
#           Video Id                                              Title  \
# 10117  QAGG4l9LsXg  Attraction Shadow Theatre Group (Royal Variety...
#
#       Description       Category
# 10117         NaN  art and music
#           Video Id                  Title Description       Category
# 10118  ZE0pudKBfEc  Patch Theatre Company         NaN  art and music
#           Video Id          Title Description       Category
# 10131  xQ_T7uVCku4  theatre niger         NaN  art and music
#           Video Id                                            Title  \
# 10138  KicAukEZY_Y  Theatre at its best | Royal Shakespeare Company
#
#       Description       Category
# 10138         NaN  art and music
#           Video Id                        Title Description       Category
# 10142  8QGuuWXZOmE  Matilda - Cambridge Theatre         NaN  art and music
#           Video Id                                     Title Description  \
# 10155  Wco1r96PRhc  World Theatre Day 2018 - Theatre Calgary         NaN
#
#             Category
# 10155  art and music
#           Video Id                                              Title  \
# 10183  GCbjbOOHbhw  Thanos In Wakanda|Theatre Reaction|Avengers In...
#
#       Description       Category
# 10183         NaN  art and music
#           Video Id             Title Description       Category
# 10248  SLbbqx9erlA  Wedding painting         NaN  art and music

# %%
print(data.shape)
data = data.dropna(how='any')
print(data.shape)
# Out:
# (10333, 4)
# (9999, 4)

# %%
data['Category'].value_counts()
# Out:
# food                      1695
# manufacturing             1673
# art and music             1672
# travel                    1671
# science and technology    1656
# history                   1632
# Name: Category, dtype: int64

# %%
#### You can download the stopwords and wordnet by uncommenting

# nltk.download('stopwords')
# nltk.download('wordnet')

# %%
stop_words = set(stopwords.words('english'))
##Creating a list of custom stopwords
new_words = ["fig","figure","image","sample","using", 
             "show", "result", "large", 
             "also", "one", "two", "three", 
             "four", "five", "seven","eight","nine"]
stop_words = list(stop_words.union(new_words))

# %%
# cleaning the data
def pre_process(text):
    
    # lowercase
    text=text.lower()
    
    #remove tags
    text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)
    
    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)
    
    ##Convert to list from string
    text = text.split()
    
    # remove stopwords
    text = [word for word in text if word not in stop_words]

    # remove words less than three letters
    text = [word for word in text if len(word) >= 3]

    # lemmatize
    lmtzr = WordNetLemmatizer()
    text = [lmtzr.lemmatize(word, "v") for word in text]
    
    return ' '.join(text)

# %%
# The frac keyword argument specifies the fraction of rows to return in the random sample
# specifying drop=True prevents .reset_index from creating a column containing the old index entries.
data = data.sample(frac=1).reset_index(drop=True)
docs = pd.DataFrame()
docs['Title'] = data['Title'].iloc[:5000].apply(lambda x:pre_process(x))
docs['Description'] = data['Description'].iloc[:5000].apply(lambda x:pre_process(x))

# %%
docs.head()
# Out:
#                                                Title  \
# 0                       digital manufacture overview
# 1             bon iver holocene official music video
# 2                              odoo manufacture tour
# 3            inside amy schumer mom computer therapy
# 4  django tutorial build travel blog goorm ide bo...
#
#                                          Description
# 0  http www capgemini com digital manufacture dig...
# 1  director nabil nabil com producer jill hammer ...
# 2  discover integrate mrp plm quality maintenance...
# 3  amy therapist help overcome intense frustratio...
# 4

# %%
# Label encoding the classes

docs['classes'] = data['Category']
docs['classes'].value_counts()
# Out:
# science and technology    856
# art and music             845
# food                      844
# travel                    838
# manufacturing             820
# history                   797
# Name: classes, dtype: int64

# %%
# Encoding classes
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(docs['classes'])
docs['classes'] = le.transform(docs['classes'])
docs.head()
# Out:
#                                                Title  \
# 0                       digital manufacture overview
# 1             bon iver holocene official music video
# 2                              odoo manufacture tour
# 3            inside amy schumer mom computer therapy
# 4  django tutorial build travel blog goorm ide bo...
#
#                                          Description  classes
# 0  http www capgemini com digital manufacture dig...        3
# 1  director nabil nabil com producer jill hammer ...        0
# 2  discover integrate mrp plm quality maintenance...        3
# 3  amy therapist help overcome intense frustratio...        4
# 4                                                           5

# %%
le.classes_
# art and music -> 0, food -> 1, and so on.
# Out:
# array(['art and music', 'food', 'history', 'manufacturing',
#        'science and technology', 'travel'], dtype=object)

# %%
docs['classes'].value_counts()
# Out:
# 4    856
# 0    845
# 1    844
# 5    838
# 3    820
# 2    797
# Name: classes, dtype: int64

# %%
# Vectorizing text features using TF-IDF


tfidf_title = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
tfidf_desc = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
labels = docs['classes']
features_title = tfidf_title.fit_transform(docs['Title']).toarray()
features_description = tfidf_desc.fit_transform(docs['Description']).toarray()
print('Title Features Shape: ' + str(features_title.shape))
print('Description Features Shape: ' + str(features_description.shape))
# Out:
# Title Features Shape: (5000, 1283)
# Description Features Shape: (5000, 2625)

# %%
# The maximum number of words to be used. (most frequent)
MAX_NB_WORDS = 10000
# Max number of words in each complaint.
MAX_SEQUENCE_LENGTH = 50
# This is fixed.
EMBEDDING_DIM = 100

# Combining titles and descriptions into a single sentence
titles = docs['Title'].values
descriptions = docs['Description'].values
data_for_lstms = []
for i in range(len(titles)):
    temp_list = [titles[i], descriptions[i]]
    data_for_lstms.append(' '.join(temp_list))

tokenizer = Tokenizer(num_words=MAX_NB_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
tokenizer.fit_on_texts(data_for_lstms)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

# Convert the data to padded sequences
X = tokenizer.texts_to_sequences(data_for_lstms)
X = pad_sequences(X, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', X.shape)

# One-hot Encode labels
Y = pd.get_dummies(docs['classes']).values
print('Shape of label tensor:', Y.shape)

# Splitting into training and test set
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, random_state = 42)
# Out:
# Found 16324 unique tokens.
# Shape of data tensor: (5000, 50)
# Shape of label tensor: (5000, 6)

# %%
titles[0:4]
# Out:
# array(['digital manufacture overview',
#        'bon iver holocene official music video', 'odoo manufacture tour',
#        'inside amy schumer mom computer therapy'], dtype=object)

# %%
data_for_lstms[0:4]
# Out:
# ['digital manufacture overview http www capgemini com digital manufacture digital change game manufacturers smart connect products assets operations offer',
#  'bon iver holocene official music video director nabil nabil com producer jill hammer production company direction editor isaac hagy dop larkin sieple boniver org jagjaguwar com',
#  'odoo manufacture tour discover integrate mrp plm quality maintenance single application maximize efficiency manufacture operations',
#  'inside amy schumer mom computer therapy amy therapist help overcome intense frustration feel whenever show mother something computer']

# %%
# Define LSTM Model
model = Sequential()
model.add(Embedding(MAX_NB_WORDS, EMBEDDING_DIM, input_length=X.shape[1]))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(6, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 50, 100)           1000000
#
#  spatial_dropout1d_2 (Spatia  (None, 50, 100)          0
#  lDropout1D)
#
#  lstm_2 (LSTM)               (None, 100)               80400
#
#  dense_2 (Dense)             (None, 6)                 606
#
# =================================================================
# Total params: 1,081,006
# Trainable params: 1,081,006
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Training LSTM Model
epochs = 25
batch_size = 128

history = model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size,validation_split=0.2)
# Out:
# Epoch 1/25
# 24/24 [==============================] - 7s 281ms/step - loss: 0.0029 - accuracy: 0.9983 - val_loss: 0.2741 - val_accuracy: 0.9560
# Epoch 2/25
# 24/24 [==============================] - 8s 328ms/step - loss: 0.0027 - accuracy: 0.9983 - val_loss: 0.2816 - val_accuracy: 0.9547
# Epoch 3/25
# 24/24 [==============================] - 7s 271ms/step - loss: 0.0023 - accuracy: 0.9987 - val_loss: 0.2774 - val_accuracy: 0.9573
# Epoch 4/25
# 24/24 [==============================] - 6s 253ms/step - loss: 0.0023 - accuracy: 0.9987 - val_loss: 0.2773 - val_accuracy: 0.9600
# Epoch 5/25
# 24/24 [==============================] - 6s 253ms/step - loss: 0.0028 - accuracy: 0.9983 - val_loss: 0.2764 - val_accuracy: 0.9613
# Epoch 6/25
# 24/24 [==============================] - 7s 272ms/step - loss: 0.0027 - accuracy: 0.9987 - val_loss: 0.2800 - val_accuracy: 0.9600
# Epoch 7/25
# 24/24 [==============================] - 6s 266ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.2972 - val_accuracy: 0.9600
# Epoch 8/25
# 24/24 [==============================] - 6s 257ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.2926 - val_accuracy: 0.9560
# Epoch 9/25
# 24/24 [==============================] - 7s 276ms/step - loss: 0.0020 - accuracy: 0.9990 - val_loss: 0.2964 - val_accuracy: 0.9587
# Epoch 10/25
# 24/24 [==============================] - 6s 265ms/step - loss: 0.0024 - accuracy: 0.9987 - val_loss: 0.2897 - val_accuracy: 0.9573
# Epoch 11/25
# 24/24 [==============================] - 7s 288ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.2962 - val_accuracy: 0.9560
# Epoch 12/25
# 24/24 [==============================] - 6s 260ms/step - loss: 0.0020 - accuracy: 0.9987 - val_loss: 0.2954 - val_accuracy: 0.9587
# Epoch 13/25
# 24/24 [==============================] - 6s 268ms/step - loss: 0.0019 - accuracy: 0.9983 - val_loss: 0.2974 - val_accuracy: 0.9587
# Epoch 14/25
# 24/24 [==============================] - 6s 243ms/step - loss: 0.0019 - accuracy: 0.9990 - val_loss: 0.3005 - val_accuracy: 0.9587
# Epoch 15/25
# 24/24 [==============================] - 6s 248ms/step - loss: 0.0021 - accuracy: 0.9987 - val_loss: 0.3005 - val_accuracy: 0.9573
# Epoch 16/25
# 24/24 [==============================] - 7s 273ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.3022 - val_accuracy: 0.9573
# Epoch 17/25
# 24/24 [==============================] - 7s 270ms/step - loss: 0.0024 - accuracy: 0.9983 - val_loss: 0.2960 - val_accuracy: 0.9613
# Epoch 18/25
# 24/24 [==============================] - 6s 266ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.2969 - val_accuracy: 0.9613
# Epoch 19/25
# 24/24 [==============================] - 7s 277ms/step - loss: 0.0014 - accuracy: 0.9993 - val_loss: 0.2945 - val_accuracy: 0.9600
# Epoch 20/25
# 24/24 [==============================] - 6s 264ms/step - loss: 0.0019 - accuracy: 0.9990 - val_loss: 0.2954 - val_accuracy: 0.9587
# Epoch 21/25
# 24/24 [==============================] - 6s 260ms/step - loss: 0.0018 - accuracy: 0.9987 - val_loss: 0.2960 - val_accuracy: 0.9600
# Epoch 22/25
# 24/24 [==============================] - 6s 258ms/step - loss: 0.0017 - accuracy: 0.9990 - val_loss: 0.2970 - val_accuracy: 0.9613
# Epoch 23/25
# 24/24 [==============================] - 6s 253ms/step - loss: 0.0022 - accuracy: 0.9983 - val_loss: 0.2967 - val_accuracy: 0.9627
# Epoch 24/25
# 24/24 [==============================] - 6s 254ms/step - loss: 0.0019 - accuracy: 0.9990 - val_loss: 0.3049 - val_accuracy: 0.9587
# Epoch 25/25
# 24/24 [==============================] - 6s 253ms/step - loss: 0.0159 - accuracy: 0.9973 - val_loss: 0.3361 - val_accuracy: 0.9587

# %%
plt.title('Loss')
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plt.title('Accuracy')
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()

# %%
# Saving the tokenizer and the model:

import pickle

pickle.dump(tokenizer, open('video_classification-tokenizer.pkl', 'wb'))
model.save('video_classification-model.h5')
